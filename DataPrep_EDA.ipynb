# %% [markdown]
# # Final Project - Data Prep
# ##### Name: Shane Staret
# ##### Class: CSCI 349 - Intro to Data Mining
# ##### Semester: 2021SP
# ##### Instructor: Brian King

# %% [markdown]
# ### **What problem are you working on?**

# %% [markdown]
# The problem is to predict student performance in secondary school based on data gathered on several hundred students.

# %% [markdown]
# ### **What data are you using to understand the problem? Describe the data in a very general sense. Where did it come from?**

# %% [markdown]
# This dataset displays student achievement in secondary education of two Portuguese schools. The data was collected using school reports and questionnaires. There are 33 total data characteristics. The data attributes include student grades, demographic, social and school related features. Two datasets are provided regarding the performance in two distinct subjects: Mathematics and Portuguese language. The two datasets were modeled under binary/five-level classification and regression tasks. The idea is to predict student performance based on the values of these 33 attributes. This data is directly from the University of Minho and is hosted by the ICS School in the University of California, Irvine (UCI).

# %% [markdown]
# ### **Preprocessing the Data**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# reading in the dataset for the math course
df_mat = pd.read_csv('data/student-mat.csv', delimiter=';')

# reading in the dataset for the Portuguese course
df_por = pd.read_csv('data/student-por.csv', delimiter=';')

# reassigning dtype for each attribute
df_mat['school'] = pd.Categorical(df_mat['school'])
df_por['school'] = pd.Categorical(df_por['school'])

df_mat['sex'] = pd.Categorical(df_mat['sex'])
df_por['sex'] = pd.Categorical(df_por['sex'])

df_mat['age'] = pd.to_numeric(df_mat['age'], downcast='unsigned')
df_por['age'] = pd.to_numeric(df_por['age'], downcast='unsigned')

df_mat['address'] = pd.Categorical(df_mat['address'])
df_por['address'] = pd.Categorical(df_por['address'])

df_mat['famsize'] = pd.Categorical(df_mat['famsize'])
df_por['famsize'] = pd.Categorical(df_por['famsize'])

df_mat['Pstatus'] = pd.Categorical(df_mat['Pstatus'])
df_por['Pstatus'] = pd.Categorical(df_por['Pstatus'])

df_mat['Medu'] = pd.Categorical(df_mat['Medu']).as_ordered()
df_por['Medu'] = pd.Categorical(df_por['Medu']).as_ordered()

df_mat['Fedu'] = pd.Categorical(df_mat['Fedu']).as_ordered()
df_por['Fedu'] = pd.Categorical(df_por['Fedu']).as_ordered()

df_mat['Mjob'] = pd.Categorical(df_mat['Mjob'])
df_por['Mjob'] = pd.Categorical(df_por['Mjob'])

df_mat['Fjob'] = pd.Categorical(df_mat['Fjob'])
df_por['Fjob'] = pd.Categorical(df_por['Fjob'])

df_mat['reason'] = pd.Categorical(df_mat['reason'])
df_por['reason'] = pd.Categorical(df_por['reason'])

df_mat['guardian'] = pd.Categorical(df_mat['guardian'])
df_por['guardian'] = pd.Categorical(df_por['guardian'])

df_mat['traveltime'] = pd.Categorical(df_mat['traveltime']).as_ordered()
df_por['traveltime'] = pd.Categorical(df_por['traveltime']).as_ordered()

df_mat['studytime'] = pd.Categorical(df_mat['studytime']).as_ordered()
df_por['studytime'] = pd.Categorical(df_por['studytime']).as_ordered()

df_mat['failures'] = pd.Categorical(df_mat['failures']).as_ordered()
df_por['failures'] = pd.Categorical(df_por['failures']).as_ordered()

df_mat['schoolsup'] = pd.Categorical(df_mat['schoolsup'])
df_por['schoolsup'] = pd.Categorical(df_por['schoolsup'])

df_mat['famsup'] = pd.Categorical(df_mat['famsup'])
df_por['famsup'] = pd.Categorical(df_por['famsup'])

df_mat['paid'] = pd.Categorical(df_mat['paid'])
df_por['paid'] = pd.Categorical(df_por['paid'])

df_mat['activities'] = pd.Categorical(df_mat['activities'])
df_por['activities'] = pd.Categorical(df_por['activities'])

df_mat['nursery'] = pd.Categorical(df_mat['nursery'])
df_por['nursery'] = pd.Categorical(df_por['nursery'])

df_mat['higher'] = pd.Categorical(df_mat['higher'])
df_por['higher'] = pd.Categorical(df_por['higher'])

df_mat['internet'] = pd.Categorical(df_mat['internet'])
df_por['internet'] = pd.Categorical(df_por['internet'])

df_mat['romantic'] = pd.Categorical(df_mat['romantic'])
df_por['romantic'] = pd.Categorical(df_por['romantic'])

df_mat['famrel'] = pd.to_numeric(df_mat['famrel'], downcast='unsigned')
df_por['famrel'] = pd.to_numeric(df_por['famrel'], downcast='unsigned')

df_mat['freetime'] = pd.to_numeric(df_mat['freetime'], downcast='unsigned')
df_por['freetime'] = pd.to_numeric(df_por['freetime'], downcast='unsigned')

df_mat['goout'] = pd.to_numeric(df_mat['goout'], downcast='unsigned')
df_por['goout'] = pd.to_numeric(df_por['goout'], downcast='unsigned')

df_mat['Dalc'] = pd.to_numeric(df_mat['Dalc'], downcast='unsigned')
df_por['Dalc'] = pd.to_numeric(df_por['Dalc'], downcast='unsigned')

df_mat['Walc'] = pd.to_numeric(df_mat['Walc'], downcast='unsigned')
df_por['Walc'] = pd.to_numeric(df_por['Walc'], downcast='unsigned')

df_mat['health'] = pd.to_numeric(df_mat['health'], downcast='unsigned')
df_por['health'] = pd.to_numeric(df_por['health'], downcast='unsigned')

df_mat['absences'] = pd.to_numeric(df_mat['absences'], downcast='unsigned')
df_por['absences'] = pd.to_numeric(df_por['absences'], downcast='unsigned')

df_mat['G1'] = pd.to_numeric(df_mat['G1'], downcast='unsigned')
df_por['G1'] = pd.to_numeric(df_por['G1'], downcast='unsigned')

df_mat['G2'] = pd.to_numeric(df_mat['G2'], downcast='unsigned')
df_por['G2'] = pd.to_numeric(df_por['G2'], downcast='unsigned')

df_mat['G3'] = pd.to_numeric(df_mat['G3'], downcast='unsigned')
df_por['G3'] = pd.to_numeric(df_por['G3'], downcast='unsigned')

display(df_mat.info())
display(df_por.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    category
#  1   sex         395 non-null    category
#  2   age         395 non-null    uint8
#  3   address     395 non-null    category
#  4   famsize     395 non-null    category
#  5   Pstatus     395 non-null    category
#  6   Medu        395 non-null    category
#  7   Fedu        395 non-null    category
#  8   Mjob        395 non-null    category
#  9   Fjob        395 non-null    category
#  10  reason      395 non-null    category
#  11  guardian    395 non-null    category
#  12  traveltime  395 non-null    category
#  13  studytime   395 non-null    category
#  14  failures    395 non-null    category
#  15  schoolsup   395 non-null    category
#  16  famsup      395 non-null    category
#  17  paid        395 non-null    category
# ...

# %%
# adding column to each df to designate the course that the students are in
df_mat['course'] = 'mat'
df_mat['course'] = pd.Categorical(df_mat['course'])
df_por['course'] = 'por'
df_por['course'] = pd.Categorical(df_por['course'])

# %%
# combine data frames for better EDA
df_com = pd.concat([df_mat, df_por], ignore_index=True)
df_com['course'] = pd.Categorical(df_com['course'])
display(df_com.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   category
#  1   sex         1044 non-null   category
#  2   age         1044 non-null   uint8
#  3   address     1044 non-null   category
#  4   famsize     1044 non-null   category
#  5   Pstatus     1044 non-null   category
#  6   Medu        1044 non-null   category
#  7   Fedu        1044 non-null   category
#  8   Mjob        1044 non-null   category
#  9   Fjob        1044 non-null   category
#  10  reason      1044 non-null   category
#  11  guardian    1044 non-null   category
#  12  traveltime  1044 non-null   category
#  13  studytime   1044 non-null   category
#  14  failures    1044 non-null   category
#  15  schoolsup   1044 non-null   category
#  16  famsup      1044 non-null   category
#  17  paid        1044 non-null   category
# ...

# %% [markdown]
# ### **Summary Statistics**

# %% [markdown]
# #### **NOTE: The data shown below HAS NOT been converted to numeric data and then standardized. This has not been done so that the data can be visualized in its original form. All input data will be converted to numeric and standardized prior to modeling.**

# %%
# histplot of number of students in each course
ax = sns.histplot(data=df_com, x="course")
ax.set_xlabel("Course")
ax.set_title("Count by Course")
plt.show()

# %% [markdown]
# The above histplot shows the number of students in the two courses demonstrated in this dataset. Clearly, there are more students in the Portuguese language course than the math course.

# %%
# histplot of number of students in each school
ax = sns.histplot(data=df_com, x="school", hue="course")
ax.set_xlabel("School")
ax.set_title("Count by School")
plt.show()

# %% [markdown]
# The above histplot shows that there are a greater proportion of students in the Portuguese language course from the MS school than in the Math course. This plot also shows that there is a greater number of students from the GP school in both courses.

# %%
# histplot of number of students by sex
ax = sns.histplot(data=df_com, x="sex", hue="course")
ax.set_xlabel("Sex")
ax.set_title("Count by Sex")
plt.show()

# %% [markdown]
# The above plot shows that there are more females than males overall in both courses. The proportion of males and females is more equal for the math course, whereas the proportion of females in the Portuguese language course is much larger than the proportion of males.

# %%
# histplot of number of students by age
ax = sns.histplot(data=df_com, x="age", hue="course")
ax.set_xlabel("Age")
ax.set_title("Count by Age")
plt.show()

# %% [markdown]
# The above graph shows that a majority of students are in their teenage years and that only a small minority are 20 or above. The age trends for both courses appear to be relatively similar, as the age trend peaks at 16-17 and then begins to fall off as age increases.

# %%
# boxplot of students by age
ax = sns.boxplot(data=df_com, x="course", y="age")
ax.set_xlabel("Course")
ax.set_ylabel("Age")
ax.set_title("Age by Course Boxplot")
plt.show()

# %% [markdown]
# From the above boxplot, it is quite clear that each course has virtually identical age distributions. We can also see that the 22 year old student in each course is the only outlier for both.

# %%
# histplot of number of students by address type by course
ax = sns.histplot(data=df_com, x="address", hue="course")
ax.set_xlabel("Address Type")
ax.set_title("Count by Address Type")
plt.show()

# %% [markdown]
# Clearly, the above plot shows that overall, there are more students from urban areas than rural. There does not appear to be much difference between courses in regards to the proportion of address types that appear.

# %%
# histplot of number of students by address type by school
ax = sns.histplot(data=df_com, x="address", hue="school")
ax.set_xlabel("Address Type")
ax.set_title("Count by Address Type")
plt.show()

# %% [markdown]
# The above plot indicates that there are many more urban students than rural students in GP, whereas there is about an even split in rural and urban students within MS.

# %%
# histplot of number of students by family size
ax = sns.histplot(data=df_com, x="famsize", hue="course")
ax.set_xlabel("Family Size")
ax.set_title("Count by Family Size")
plt.show()

# %% [markdown]
# About 2/3 of the student body has a family size 4 or greater, whereas the other third have a family size of 3 or less. This proportion appears to be be maintained in each class.

# %%
# histplot of number of students by parent cohabitation status
ax = sns.histplot(data=df_com, x="Pstatus", hue="course")
ax.set_xlabel("Parent Cohabitation Status")
ax.set_title("Count by Parent Cohabitation Status")
plt.show()

# %% [markdown]
# From the above plot it is clear that a majority of students have parents that live together. There does not appear to be any notable differences in proportion when looking at each class separately.

# %%
# histplot of number of students by Mother's education
ax = sns.histplot(data=df_com, x="Medu", hue="course")
ax.set_xlabel("Mother's Education")
ax.set_title("Count by Mother's Education")
plt.show()

# %% [markdown]
# Here are what the categories represent: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education. There are an extremely small number of student's whose mothers had no education. The other four possibilities appear to have a relatively similar count. Interestingly, there are some moderate differences by course. It appears that the math course has a higher proportion of students with mother's who have a higher education compared to students in the Portuguese language course. Also, it appears that there are a greater proportion of students in the Portuguese language course who have mothers with a 5th to 9th grade education compared to those in the math course.

# %%
# histplot of number of students by Father's education
ax = sns.histplot(data=df_com, x="Fedu", hue="course")
ax.set_xlabel("Father's Education")
ax.set_title("Count by Father's Education")
plt.show()

# %% [markdown]
# Here are what the categories represent: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education. There are an extremely small number of student's whose fathers had no education. Unlike the counts for mothers education, it appears that there are no course-specific differences. Overall, it appears that there are more mothers with a higher education compared to fathers.

# %%
# histplot of number of students by Mother's job
ax = sns.histplot(data=df_com, x="Mjob", hue="course")
ax.set_xlabel("Mother's Job")
ax.set_title("Count by Mother's Job")
plt.show()

# %% [markdown]
# There do not appear to be many proporitional differences by course. If anything, it seems that students in the math course are more likely to have mothers in the civil service industry compared to those who stay at home, while the opposite is true for the Portuguese language course. Overall, it appears that the greatest proportion of mothers do not have a job in health care, civil services, or as a teacher.

# %%
# histplot of number of students by Father's job
ax = sns.histplot(data=df_com, x="Fjob", hue="course")
ax.set_xlabel("Father's Job")
ax.set_title("Count by Father's Job")
plt.show()

# %% [markdown]
# Based on the above plot, there are very little proportional differences by course in regards to the kind of job each student's father has. Interestingly, it appears that there are less stay-at-home father's compared to stay-at-home mothers and this is true for teachers and health care as well. In other words, it seems that fathers are more likely to be in the civil service or "other" industry compared to mothers.

# %%
# histplot of number of students by reason by course
ax = sns.histplot(data=df_com, x="reason", hue="course")
ax.set_xlabel("Reason")
ax.set_title("Count by Reason")
plt.show()

# %% [markdown]
# There does not appear to be any course specific trends. In both courses, the majority of students made their school choice based on course selection.

# %%
# histplot of number of students by reason by school
ax = sns.histplot(data=df_com, x="reason", hue="school")
ax.set_xlabel("Reason")
ax.set_title("Count by Reason")
plt.show()

# %% [markdown]
# The above plot shows that a greater proportion of students chose to attend MS for reasons other than listed compared to GP students.

# %%
# histplot of number of students by guardian
ax = sns.histplot(data=df_com, x="guardian", hue="course")
ax.set_xlabel("Guardian")
ax.set_title("Count by Guardian")
plt.show()

# %% [markdown]
# There are not many difference in student's guardians by course. Interestingly though, most students have their mother as their listed guardian.

# %%
# histplot of number of students by travel time by course
ax = sns.histplot(data=df_com, x="traveltime", hue="course")
ax.set_xlabel("Travel Time")
ax.set_title("Count by Travel Time")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %% [markdown]
# Here are what the categories represent: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour. Obviously, the greatest proportion of students have less than 15 minutes of travel time, and the longer the travel time the less likely a student is to have that travel time. There does not appear to be any obvious course specific differences.

# %%
# histplot of number of students by travel time by school
ax = sns.histplot(data=df_com, x="traveltime", hue="school")
ax.set_xlabel("Travel Time")
ax.set_title("Count by Travel Time")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %% [markdown]
# Based on the above plot, there are school-specific differences in travel time. The greatest proportion of students in the GP school travel less than 15 mins, whereas the greatest proportion of students in the MS school travel between 15 and 30 mins. Also, it appears that in general, MS students have to travel longer than GP students.

# %%
# histplot of number of students by weekly study time
ax = sns.histplot(data=df_com, x="studytime", hue="course")
ax.set_xlabel("Weekly Study Time")
ax.set_title("Count by Weekly Study Time")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %% [markdown]
# Here are what the categories represent: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours. It appears that students in the math course are more likely to study longer hours (5+) compared to students within the Portuguese language course.

# %%
# histplot of number of students by number of past failures
ax = sns.histplot(data=df_com, x="failures", hue="course")
ax.set_xlabel("Number of Past Failures")
ax.set_title("Count by Number of Past Failures")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %% [markdown]
# Clearly, the majority of students had no past class failures. Interestingly, it seems that the math and Portuguese language course had about the same number of students who failed 2 or 3 times in the past, indicating that there is a higher proportion of students in the math course who have failed 2 or 3 times compared to the proportion in the Portuguese language course.

# %%
# histplot of number of students by school support by course
ax = sns.histplot(data=df_com, x="schoolsup", hue="course")
ax.set_xlabel("School Support")
ax.set_title("Count by School Support")
plt.show()

# %% [markdown]
# Based on the graph above, a greater proportion of math students are given school support compared to Portuguese language students.

# %%
# histplot of number of students by school support by school
ax = sns.histplot(data=df_com, x="schoolsup", hue="school")
ax.set_xlabel("School Support")
ax.set_title("Count by School Support")
plt.show()

# %% [markdown]
# Clearly, a greater proportion of students in the GP school are given school support compared to the MS school.

# %%
# histplot of number of students by family educational support by course
ax = sns.histplot(data=df_com, x="famsup", hue="course")
ax.set_xlabel("Family Educational Support")
ax.set_title("Count by Family Educational Support")
plt.show()

# %% [markdown]
# There appear to be no course-specific differences, as regardless of the course most students receive family educational support.

# %%
# histplot of number of students by family educational support by school
ax = sns.histplot(data=df_com, x="famsup", hue="school")
ax.set_xlabel("Family Educational Support")
ax.set_title("Count by Family Educational Support")
plt.show()

# %% [markdown]
# Interestingly, it appears that families of students who go to the GP school are more likely to provide educational support compared to families of students who go to the MS school.

# %%
# histplot of number of students by their status of taking other paid courses within the subject by course
ax = sns.histplot(data=df_com, x="paid", hue="course")
ax.set_xlabel("Other Paid Courses")
ax.set_title("Count by Other Paid Courses")
plt.show()

# %% [markdown]
# Based on the above graph, students in the math course were clearly more likely to have taken paid courses within the subject matter. Just under half of all math students have paid for another course in the same subject, whereas it seems that less than 10% of Portuguese language students did the same.

# %%
# histplot of number of students by their status of taking other paid courses within the subject by school
ax = sns.histplot(data=df_com, x="paid", hue="school")
ax.set_xlabel("Other Paid Courses")
ax.set_title("Count by Other Paid Courses")
plt.show()

# %% [markdown]
# The above plot shows that students who go to GP are more likely to pay for other courses in a similar subject matter compared to students going to MS.

# %%
# histplot of number of students by their participation in extracurricular activities by course
ax = sns.histplot(data=df_com, x="activities", hue="course")
ax.set_xlabel("Participation in Extracurricular Activities")
ax.set_title("Count by Participation in Extracurricular Activities")
plt.show()

# %% [markdown]
# There does not appear to be any course-specific differences regarding participation in extracurricular activitues

# %%
# histplot of number of students by their participation in extracurricular activities by school
ax = sns.histplot(data=df_com, x="activities", hue="school")
ax.set_xlabel("Participation in Extracurricular Activities")
ax.set_title("Count by Participation in Extracurricular Activities")
plt.show()

# %% [markdown]
# There appears to be only a very minor difference in extracurricular participation by school. It seems that GP students are more likely to participate than MS students.

# %%
# histplot of number of students by their attendance of nursery school by course
ax = sns.histplot(data=df_com, x="nursery", hue="course")
ax.set_xlabel("Attendance of Nursery School")
ax.set_title("Count by Attendance of Nursery School")
plt.show()

# %% [markdown]
# There does not seem to be any significant course-specific differences regarding attendance of nursery school.

# %%
# histplot of number of students by their attendance of nursery school by school
ax = sns.histplot(data=df_com, x="nursery", hue="school")
ax.set_xlabel("Attendance of Nursery School")
ax.set_title("Count by Attendance of Nursery School")
plt.show()

# %% [markdown]
# Similarly, there does not seem to be any significant school-specific differences regarding attendance of nursery school.

# %%
# histplot of number of students by their desire to attend higher education by course
ax = sns.histplot(data=df_com, x="higher", hue="course")
ax.set_xlabel("Desire for Higher Education")
ax.set_title("Count by Desire for Higher Education")
plt.show()

# %% [markdown]
# Based on the above plot, it is clear that a greater proportion of math students desire higher education compared to Portuguese language students.

# %%
# histplot of number of students by their desire to attend higher education by school
ax = sns.histplot(data=df_com, x="higher", hue="school")
ax.set_xlabel("Desire for Higher Education")
ax.set_title("Count by Desire for Higher Education")
plt.show()

# %% [markdown]
# Quite clearly, a greater proportion of GP students want to attend higher education compared to MS students.

# %%
# histplot of number of students by internet access by course
ax = sns.histplot(data=df_com, x="internet", hue="course")
ax.set_xlabel("Internet Access")
ax.set_title("Count by Internet Access")
plt.show()

# %% [markdown]
# There does not appear to be any significant course-specific differences, though it seems that math students are slightly more likely to have internet access than Portuguese language students.

# %%
# histplot of number of students by internet access by school
ax = sns.histplot(data=df_com, x="internet", hue="school")
ax.set_xlabel("Internet Access")
ax.set_title("Count by Internet Access")
plt.show()

# %% [markdown]
# The above graph quite clearly shows that GP students are much more likely to have internet access compared to MS students.

# %%
# histplot of number of students by relationship status
ax = sns.histplot(data=df_com, x="romantic", hue="course")
ax.set_xlabel("Relationship Status")
ax.set_title("Count by Relationship Status")
plt.show()

# %% [markdown]
# Based on the above histplot, a majority of students appear to not be in a relationship and there are no course-specific differences.

# %%
# histplot of number of students by quality of family relationships
ax = sns.histplot(data=df_com, x="famrel", hue="course")
ax.set_xlabel("Family Relationship Status")
ax.set_title("Count by Family Relationship Status")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %% [markdown]
# 1 indicates a "very bad" family relationship whereas 5 represents an "excellent" family relationship. This appears to cluster around 4-5 and there does not appear to be any course-specific differences.

# %%
# histplot of number of students by free time after school
ax = sns.histplot(data=df_com, x="freetime", hue="course")
ax.set_xlabel("Free Time After School")
ax.set_title("Count by Free Time After School")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %% [markdown]
# 1 indicates "very low" free time whereas 5 represents "very high" free time. This appears to cluster around 3-4 and there does not appear to be any course-specific differences.

# %%
# histplot of number of students by how often they go out with friends
ax = sns.histplot(data=df_com, x="goout", hue="course")
ax.set_xlabel("Go Out with Friends Frequency")
ax.set_title("Count by Go Out with Friends Frequency")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %% [markdown]
# 1 indicates "very low" frequency of going out with friends whereas 5 represents "very high" frequency of going out with friends. This appears to cluster around 3 and there does not appear to be any course-specific differences.

# %%
# histplot of number of students by workday alcohol consumption
ax = sns.histplot(data=df_com, x="Dalc", hue="course")
ax.set_xlabel("Workday Alcohol Consumption Frequency")
ax.set_title("Count by Workday Alcohol Consumption Frequency")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %% [markdown]
# 1 indicates "very low" frequency of workday alcohol consumption whereas 5 represents "very high" frequency of workday alcohol consumption. Clearly, a majority of students have a very low frequency of workday alcohol consumption and there does not appear to be any course-specific differences.

# %%
# histplot of number of students by weekend alcohol consumption
ax = sns.histplot(data=df_com, x="Walc", hue="course")
ax.set_xlabel("Weekend Alcohol Consumption Frequency")
ax.set_title("Count by Weekend Alcohol Consumption Frequency")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %% [markdown]
# 1 indicates "very low" frequency of weekend alcohol consumption whereas 5 represents "very high" frequency of weekend alcohol consumption. Unlike workday alcohol consumption, weekend alcohol consumption is much more spread out, though the highest proportion of students still drink very low frequencies of alcohol on the weekend. Again, there does not appear to be any course-specific differences.

# %%
# histplot of number of students by health status
ax = sns.histplot(data=df_com, x="health", hue="course")
ax.set_xlabel("Health Status")
ax.set_title("Count by Health Status")
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %% [markdown]
# 1 indicates "very bad" health whereas 5 represents "very good" health. Most students appear to fall into the very good health category, with the other categories having relatively similar proportions. There does not appear to be any course-specific differences.

# %%
# boxplot of students by number of absences by course
ax = sns.boxplot(data=df_com, x="course", y="absences")
ax.set_xlabel("Course")
ax.set_ylabel("# Absences")
ax.set_title("# Absences by Course Boxplot")
plt.show()

# %% [markdown]
# Interestingly, it appears that math students have a higher number of absences in general. Also, the students that have a very large number of absences (40 and above) only appear in the math course.

# %%
# boxplot of students by number of absences by school
ax = sns.boxplot(data=df_com, x="school", y="absences")
ax.set_xlabel("School")
ax.set_ylabel("# Absences")
ax.set_title("# Absences by School Boxplot")
plt.show()

# %% [markdown]
# The above boxplot clearly shows that GP students generally have a larger number of absences compared to MS students. Also, students containing an extreme number of absences appear to all come from the GP school rather than the MS school.

# %%
# boxplot of students by first period grade
ax = sns.boxplot(data=df_com, x="course", y="G1")
ax.set_xlabel("Course")
ax.set_ylabel("1st Period Grade")
ax.set_title("1st Period Grade by Course Boxplot")
plt.show()

# %% [markdown]
# Overall, it appears that the Portuguese language course saw a wider range of grades compared to the math course. Interestingly though, the majority of data for the language course appears to be tightly clustered together compared to the math course, there are just 5 outliers in the language course that make the range wider.

# %%
# boxplot of students by second period grade
ax = sns.boxplot(data=df_com, x="course", y="G2")
ax.set_xlabel("Course")
ax.set_ylabel("2nd Period Grade")
ax.set_title("2nd Period Grade by Course Boxplot")
plt.show()

# %% [markdown]
# This plot shows that the second period grade distributions were quite similar to the first period. Again, the Portuguese language course has more outliers, but an overall tighter grouping of scores compared to the math course.

# %%
# boxplot of students by final grade by course
ax = sns.boxplot(data=df_com, x="course", y="G3")
ax.set_xlabel("Course")
ax.set_ylabel("Final Grade")
ax.set_title("Final Grade by Course Boxplot")
plt.show()

# %% [markdown]
# Overall, it appears that the math course saw a wider range of grades compared to the Portuguese language course. Scores below 5 were not considered outliers for the math course, but they were for the Portuguese language course. The Portuguese language course also appears to have had a slightly higher median score compared to the math course and a tighter range of scores in general.

# %%
# boxplot of students by final grade by school
ax = sns.boxplot(data=df_com, x="school", y="G3")
ax.set_xlabel("School")
ax.set_ylabel("Final Grade")
ax.set_title("Final Grade by School Boxplot")
plt.show()

# %% [markdown]
# Overall, it appears that the GP school contained higher average scores than the MS school, though not very significantly. The MS school only contained one student that performed very poorly whereas the GP school contained two. Also, the MS school appeared to have a slightly tighter range of scores compared to the GP school.

# %%
# boxplot of students by final grade by school (with course as hue)
ax = sns.boxplot(data=df_com, x="school", y="G3", hue="course")
ax.set_xlabel("School")
ax.set_ylabel("Final Grade")
ax.set_title("Final Grade by School Boxplot")
plt.show()

# %% [markdown]
# It appears that in general, GP students performed better in both courses compared to MS students. However, while the average GP student may have done better than the average MS student, it appears that the GP school was more likely to have low performers than the MS school, as the bottom of the boxplot for the GP math course extends to 0, whereas the boxplot for the MS math course only extends to 5. Similarly, the GP school has 4 low performing outliers for the Portuguese language course, whereas the MS school only has 1.

# %% [markdown]
# ### **Possible Modeling Methods**

# %% [markdown]
# Given that we are attempting to predict numeric final grades for each student, it is clear that this could be a regression DM problem. Perhaps standard or hierarchical multiple regression can be used depending on if the relevancy of each variable is considered to be equal or not. I suspect that there will be several irrelevant variables within this dataset, so hierarchical multiple regression may be the way to go. However, the numeric nature of the scores (from 0-20) can be made categorical, effectively eliminating the need for this just to be a regression DM problem and allowing us to apply classification models to it as well. Thus, utilizing Keras and a NN to create a model may also be an option (and potentially, the better option).
#
# There is one [research paper](http://www3.dsi.uminho.pt/pcortez/student.pdf) that used this dataset to determine variables that are relevant to predicting student performance. They obviously used regression DM methods as well, however, they also broke down this problem so that classification DM methods could also be applied. Scores range from 0 to 20, so they classified scores of 10 and below as being "failures" and 11 and above as being "successes". They were then able to apply certain classification methods (e.g. decision trees) to this problem as well.
#
# For this specific project, I will be focused on using a regression method as well as using a Keras NN model. After reading through the one research paper addressing this dataset, a method utilizing a NN should be a successful approach to this problem and should deliver interpretable and meaningful results **so long as the first period grades and second period grades are included, not just the final grade**. Also, this is mentioned in the "Conclusion" section of the research paper. I will be running the Keras NN model on a version of the dataset that does not contain the first period and second period grades, and see if I get inconclusive results as predicted by the paper. I will also run this model on a complete version of the dataset with these two periods included, to see if accuracy is much higher.

# %% [markdown]
# ### **Finally, what is your overarching aim with this project? What are you hoping to learn? Or, what hypothesis are you using the data to confirm or disprove? What challenges do you foresee on this project? Discuss your concerns. How will you get your work done? Give a reasonable list of milestones to reach to arrive at the final deadline for the project.**

# %% [markdown]
# The overarching aim of this project is to simply understand what variables within a student's life may predict their performance within certain courses. Personally, I am hoping to learn what attributes are of greatest significance and which ones are irrelevant to see if reasons given in modern times for why students succeed or fail have any merit. Particularly, I am curious to see how a student's family situation impacts their success or failure chance, as there are several family variables (e.g. Mjob, Fjob, famrel, etc) included in this dataset and it would be interesting to see how relevant/irrelevant the values of these attributes are.
#
# I do foresee some challenges occurring though. There are over 30 total variables for each student in this dataset, meaning it is one with high dimensionality. We may find that most of these variables are irrelevant and it may be difficult to garner accurate model predictions because of the sparsity that can come with high-dimensional data.
#
# The first part of getting my work completed has already been done with the completion of this notebook. But much more work is to come. I think a majority of my time must be spent working through different models that can apply to this dataset to predict performance.
# By the end of the project there are several milestones that need to be accomplished:
# * an effective EDA that properly visualizes the data and its many attributes
# * the use of a model or models that satisfactorily predict performance based on the relevant variables contained within the dataset
# * a proper interpretation of the predictions given by the models and what these interpretations imply
# * an explanation of the importance of this project and why solving the problem presented is important and how findings within this project may be applied to future research within the education space
